# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"c:/Users/Jaya/Downloads/covid_19_data.csv")

# %%
data.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
data.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
data.tail()
# Out:
#          SNo ObservationDate Province/State  Country/Region  \
# 13524  13525      04/09/2020        Wyoming              US
# 13525  13526      04/09/2020       Xinjiang  Mainland China
# 13526  13527      04/09/2020          Yukon          Canada
# 13527  13528      04/09/2020         Yunnan  Mainland China
# 13528  13529      04/09/2020       Zhejiang  Mainland China
#
#                Last Update  Confirmed  Deaths  Recovered
# 13524  2020-04-09 23:09:19      230.0     0.0        0.0
# 13525  2020-04-09 23:09:19       76.0     3.0       73.0
# 13526  2020-04-09 23:09:19        7.0     0.0        0.0
# 13527  2020-04-09 23:09:19      184.0     2.0      173.0
# 13528  2020-04-09 23:09:19     1267.0     1.0     1235.0

# %%
data.describe
# Out:
# <bound method NDFrame.describe of          SNo ObservationDate            Province/State  Country/Region  \
# 0          1      01/22/2020                     Anhui  Mainland China
# 1          2      01/22/2020                   Beijing  Mainland China
# 2          3      01/22/2020                 Chongqing  Mainland China
# 3          4      01/22/2020                    Fujian  Mainland China
# 4          5      01/22/2020                     Gansu  Mainland China
# 5          6      01/22/2020                 Guangdong  Mainland China
# 6          7      01/22/2020                   Guangxi  Mainland China
# 7          8      01/22/2020                   Guizhou  Mainland China
# 8          9      01/22/2020                    Hainan  Mainland China
# 9         10      01/22/2020                     Hebei  Mainland China
# 10        11      01/22/2020              Heilongjiang  Mainland China
# 11        12      01/22/2020                     Henan  Mainland China
# ...

# %%
data.isnull().sum()
# Out:
# SNo                   0
# ObservationDate       0
# Province/State     6562
# Country/Region        0
# Last Update           0
# Confirmed             0
# Deaths                0
# Recovered             0
# dtype: int64

# %%
data.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %% [markdown]
# # relating the variables with scatterplots

# %%
sns.relplot(x="Confirmed",y="Recovered",hue="Recovered",data=data)

# %%
sns.relplot(x="Confirmed",y="Deaths",hue="Recovered",data=data)

# %%
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
data
# Out:
#          SNo ObservationDate            Province/State  Country/Region  \
# 0          1      01/22/2020                     Anhui  Mainland China
# 1          2      01/22/2020                   Beijing  Mainland China
# 2          3      01/22/2020                 Chongqing  Mainland China
# 3          4      01/22/2020                    Fujian  Mainland China
# 4          5      01/22/2020                     Gansu  Mainland China
# 5          6      01/22/2020                 Guangdong  Mainland China
# 6          7      01/22/2020                   Guangxi  Mainland China
# 7          8      01/22/2020                   Guizhou  Mainland China
# 8          9      01/22/2020                    Hainan  Mainland China
# 9         10      01/22/2020                     Hebei  Mainland China
# 10        11      01/22/2020              Heilongjiang  Mainland China
# 11        12      01/22/2020                     Henan  Mainland China
# ...

# %%
data.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
sns.relplot(x="Confirmed",y="Recovered",kind="line",data=data)

# %%
data.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
sns.catplot(x="Confirmed",y="Recovered",data=data)
